# %% [markdown]
# # Healthcare: Medical Insurance Cost Prediction
#
# ## Objective
#  The objective of this project is to clean the insurance dataset,
#  explore the data to discover patterns and relationships, and build
#  a machine learning model capable of predicting medical insurance charges.

# %% [markdown]
# **Import Required Libraries**

# %%
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", None)

#scikit-learn library
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

import warnings
warnings.filterwarnings("ignore")

# %%
# Load dataset into a pandas DataFrame
df = pd.read_csv("insurance.csv")

# View the first few rows of the dataset
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# **Data Cleaning**
#
# *Inspect Dataset*

# %%
# Overview of the dataset
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   str
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   str
#  5   region    1338 non-null   str
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), str(3)
# memory usage: 73.3 KB

# %%
df.shape
# Out:
# (1338, 7)

# %% [markdown]
# **Observations**
#
# - Dataset contains **1338 row**
# - 7 column
# - Correct data types
# - No obvious datatype issue

# %%
# Summary statistics of the dataset
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# Categorical columns in the dataset
df.describe(include=['object'])
# Out:
#          sex smoker     region
# count   1338   1338       1338
# unique     2      2          4
# top     male     no  southeast
# freq     676   1064        364

# %%
# Numerical columns in the dataset
numerical_cols = df.select_dtypes(include=["int64", "float64"]).columns.tolist()

numerical_cols
# Out:
# ['age', 'bmi', 'children', 'charges']

# %% [markdown]
# **0bservations**
#
# *Statistic summary*
# - Charges vary greatly
# - BMI range from healthy to Obese
# - Maximum insurance charge is significantly larger than the average
#
# *Categorical variable include*
# - Sex
# - Smoker
# - Region
# - No inconsistent spellings were observed
#
# *Numerical column*
# - All columns are stored with the right datatypes

# %%
# Check Duplicated Records
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
# Remove Duplicated Records

df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Observations**
#
# - There is one duplicated Row
# - It was successfully removed

# %% [markdown]
# **Understanding the Dataset**
#
# | Variable | Description                              |
# | -------- | ---------------------------------------- |
# | age      | Age of beneficiary                       |
# | sex      | Male/Female                              |
# | bmi      | Body Mass Index                          |
# | children | Number of dependents                     |
# | smoker   | Smoking status                           |
# | region   | Residential region                       |
# | charges  | Medical insurance cost (Target Variable) |

# %% [markdown]
# **Data Quality Check**

# %%
# Missing Values Check
df.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# **0bservations**
#
# - There are no *MISSING VALUES* in the dataset
# - The dataset is rady for *EDA*

# %% [markdown]
# **EXPLORATORY DATA ANALYSIS (EDA)**

# %%
# Visualization of each column 

df.hist(figsize=(12,8))
plt.show()

# %% [markdown]
# **Observation**
# - Age is fairly distributed
# - BMI appears normally distributed
# - Charges are highly right-skewed

# %%
#Age Distribution

plt.figure(figsize=(8,5))
sns.histplot(df['age'], bins=20, kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **Observation**
#
#  The population is fairly distributed across different age groups with a slight concentration among younger adults.

# %%
#Age vs Insurance Charges

plt.figure(figsize=(8,5))
sns.scatterplot(x='age', y='charges', data=df)
plt.title('Age vs Insurance Charges')
plt.xlabel('Age')
plt.ylabel('Medical Charges')
plt.show()

# %% [markdown]
# ### Interpretation
# -	The dataset contains individuals between ages 18 and 64.
# -	Most policyholders are concentrated between 20 and 50 years.
# -	Medical insurance charges generally increase with age.
# -	Older individuals tend to incur higher healthcare costs than younger individuals.
#
# ### Key Finding
# Age has a positive relationship with insurance charges, indicating that healthcare expenses increase as people grow older.

# %% [markdown]
# ### BMI Analysis Visualization
#
# **Objective**
# To determine the effect of Body Mass Index (BMI) on insurance charges.

# %%
#BMI Distribution

plt.figure(figsize=(8,5))
sns.histplot(df['bmi'], bins=20, kde=True)
plt.title('BMI Distribution')
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **Observation**
#
# Most policyholders have BMI levels indicating overweight conditions.

# %%
#BMI vs Charges

plt.figure(figsize=(8,5))
sns.scatterplot(x='bmi', y='charges', data=df)
plt.title('BMI vs Insurance Charges')
plt.xlabel('BMI')
plt.ylabel('Medical Charges')
plt.show()

# %% [markdown]
# **Interpretation**
#
# -	BMI values are approximately normally distributed.
# -	Most individuals have BMI values between 25 and 35.
# -	Insurance charges tend to increase as BMI increases.
# -	Individuals with BMI above 30 generally have higher medical expenses.
#
# **Key Finding:**
# BMI shows a positive correlation with insurance charges, suggesting that obesity-related health risks contribute to increased healthcare costs.

# %%
#Charges Distribution

plt.figure(figsize=(8,5))
sns.histplot(df['charges'], bins=30, kde=True)
plt.title('Distribution of Insurance Charges')
plt.show()

# %% [markdown]
# **Observation**
#
# The target variable is right-skewed, indicating a few individuals incur extremely high medical costs

# %%
#Boxplot of BMI

plt.figure(figsize=(8,5))
sns.boxplot(x=df['bmi'])
plt.title('BMI Boxplot')
plt.show()

# %% [markdown]
# A few BMI outliers exist, representing individuals with exceptionally high body mass index values.

# %% [markdown]
# ## EDA Insights
#
# **Summary of Findings**
#
# *Age*
# -	Age is positively correlated with medical insurance charges.
# -	Older individuals generally pay higher insurance costs.
# -	Healthcare expenses increase progressively with age
#
# *BMI*
# -	BMI is positively associated with insurance charges.
# -	Individuals with higher BMI values tend to incur larger medical expenses.
# -	Obesity appears to be an important factor affecting healthcare costs.
#
# *Distribution of Charges*
#
# -	Insurance charges are highly skewed.
# -	A small number of policyholders generate very high medical costs.
#
# *Business Implications*
#
# i.	 Age significantly influences healthcare expenditure and should be retained as a key predictive feature.
#
# ii.	 BMI contributes meaningfully to medical costs and should be included in predictive models.
#
# iii. Insurance providers can use age and BMI information to better estimate future healthcare expenses.
#
# iv.	 Preventive health programs targeting obesity may help reduce long-term medical costs.

# %%
# Check the distribution of the 'Sex' column
df['sex'].value_counts()
# Out:
# sex
# male      675
# female    662
# Name: count, dtype: int64

# %%
# Check the distribution of the 'Region' column
df['region'].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    324
# northeast    324
# Name: count, dtype: int64

# %%
# Check the distribution of the 'Smoker' column
df['smoker'].value_counts()
# Out:
# smoker
# no     1063
# yes     274
# Name: count, dtype: int64

# %%
# Describe the 'charges' column for each category in the 'Sex' column
df.groupby('sex')['charges'].describe()
# Out:
#         count          mean           std        min          25%        50%  \
# sex
# female  662.0  12569.578844  11128.703801  1607.5101  4885.158700  9412.9625
# male    675.0  13974.998864  12971.958663  1121.8739  4654.022675  9377.9047
#
#                  75%          max
# sex
# female  14454.691825  63770.42801
# male    19006.685500  62592.87309

# %%
# Describe the 'smoker' column for each category in the 'charges' column
df.groupby("smoker")["charges"].describe()
# Out:
#          count          mean           std         min           25%  \
# smoker
# no      1063.0   8440.660307   5992.973800   1121.8739   3988.883500
# yes      274.0  32050.231832  11541.547176  12829.4551  20826.244213
#
#                 50%           75%          max
# smoker
# no       7345.72660  11363.019100  36910.60803
# yes     34456.34845  41019.207275  63770.42801

# %%
# Describe the 'charges' column for each category in the 'Region' column
df.groupby('region')['charges'].describe()
# Out:
#            count          mean           std        min          25%  \
# region
# northeast  324.0  13406.384516  11255.803066  1694.7964  5194.322288
# northwest  324.0  12450.840844  11073.125699  1621.3402  4733.635288
# southeast  364.0  14735.411438  13971.098589  1121.8739  4440.886200
# southwest  325.0  12346.937377  11557.179101  1241.5650  4751.070000
#
#                     50%           75%          max
# region
# northeast  10057.652025  16687.364100  58571.07448
# northwest   8976.977250  14788.747863  60021.39897
# southeast   9294.131950  19526.286900  63770.42801
# southwest   8798.593000  13462.520000  52590.82939

# %%
# Visualize the distribution of 'charges' for each category in the 'Smoker' column
sns.boxplot(data= df, x = "smoker", y = "charges")
plt.show()

# %%
# Describe the 'charges' column for each category in the 'Sex' and 'Smoker' columns
df.groupby(['sex', 'smoker'])['charges'].describe()
# Out:
#                count          mean           std         min           25%  \
# sex    smoker
# female no      547.0   8762.297300   6060.775970   1607.5101   4265.599100
#        yes     115.0  30678.996276  11907.536381  13844.5060  19696.432100
# male   no      516.0   8099.700161   5907.000174   1121.8739   3684.907500
#        yes     159.0  33042.005975  11202.670862  12829.4551  21241.526875
#
#                         50%          75%          max
# sex    smoker
# female no       7639.417450  11786.16660  36910.60803
#        yes     28950.469200  40918.31450  63770.42801
# male   no       6986.101975  10960.85900  32108.66282
#        yes     36085.219000  41797.58905  62592.87309

# %%
# Describe the 'charges' column for each category in the 'Region' and 'Smoker' columns
df.groupby(['region', 'smoker'])['charges'].describe()
# Out:
#                   count          mean           std         min           25%  \
# region    smoker
# northeast no      257.0   9165.531672   6157.196439   1694.7964   4438.263400
#           yes      67.0  29673.536473  11589.559770  12829.4551  19881.400425
# northwest no      266.0   8582.467101   6125.331366   1621.3402   4201.807987
#           yes      58.0  30192.003182  11413.827702  14711.7438  20834.130337
# southeast no      273.0   8032.216309   6137.329758   1121.8739   3471.409600
#           yes      91.0  34844.996824  11324.766536  16577.7795  23155.105450
# southwest no      267.0   8019.284513   5489.514421   1241.5650   3947.026500
#           yes      58.0  32269.063494  11270.279593  13844.5060  20396.042022
#
#                            50%           75%          max
# region    smoker
# northeast no       8342.908750  11938.255950  32108.66282
#           yes     28101.333050  39576.950850  58571.07448
# ...

# %% [markdown]
# ### Feature Engineering, Feature Encoding

# %% [markdown]
# **Label Encoder**

# %%
# Encode categorical variables
le = LabelEncoder() #create an instance
df["sex"] = le.fit_transform(df["sex"]) #transform each categorical column
df["smoker"] = le.fit_transform(df["smoker"])

# %%
# Check the column names in the DataFrame
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='str')

# %%
df.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges
# 0   19    0  27.900         0       1  southwest  16884.92400
# 1   18    1  33.770         1       0  southeast   1725.55230
# 2   28    1  33.000         3       0  southeast   4449.46200
# 3   33    1  22.705         0       0  northwest  21984.47061
# 4   32    1  28.880         0       0  northwest   3866.85520

# %% [markdown]
# ### One Hot Encoder

# %%
df_encoded = df.copy()

# %%
df_encoded = pd.get_dummies(df, columns=["region"], dtype=int)

# %%
df_encoded.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges',
#        'region_northeast', 'region_northwest', 'region_southeast',
#        'region_southwest'],
#       dtype='str')

# %%
df_encoded.head()
# Out:
#    age  sex     bmi  children  smoker      charges  region_northeast  \
# 0   19    0  27.900         0       1  16884.92400                 0
# 1   18    1  33.770         1       0   1725.55230                 0
# 2   28    1  33.000         3       0   4449.46200                 0
# 3   33    1  22.705         0       0  21984.47061                 0
# 4   32    1  28.880         0       0   3866.85520                 0
#
#    region_northwest  region_southeast  region_southwest
# 0                 0                 0                 1
# 1                 0                 1                 0
# 2                 0                 1                 0
# 3                 1                 0                 0
# 4                 1                 0                 0

# %%
df_encoded.dtypes
# Out:
# age                   int64
# sex                   int64
# bmi                 float64
# children              int64
# smoker                int64
# charges             float64
# region_northeast      int64
# region_northwest      int64
# region_southeast      int64
# region_southwest      int64
# dtype: object

# %% [markdown]
# ### Train-test Split

# %%
#X is the independent variable - features
#y is the dependent variable - target

x = df_encoded.drop("charges", axis=1)
y = df_encoded["charges"]

# %%
#80:20 ratio
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train.shape
# Out:
# (1069, 9)

# %%
x_test.shape
# Out:
# (268, 9)

# %%
x_train.head()
# Out:
#       age  sex     bmi  children  smoker  region_northeast  region_northwest  \
# 1114   23    1  24.510         0       0                 1                 0
# 968    21    1  25.745         2       0                 1                 0
# 599    52    0  37.525         2       0                 0                 1
# 170    63    1  41.470         0       0                 0                 0
# 275    47    0  26.600         2       0                 1                 0
#
#       region_southeast  region_southwest
# 1114                 0                 0
# 968                  0                 0
# 599                  0                 0
# 170                  1                 0
# 275                  0                 0

# %%
x_train.dtypes
# Out:
# age                   int64
# sex                   int64
# bmi                 float64
# children              int64
# smoker                int64
# region_northeast      int64
# region_northwest      int64
# region_southeast      int64
# region_southwest      int64
# dtype: object

# %% [markdown]
# ### Feature Scaling

# %%
#Standard Scaler (Mean=0, std=1)

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
x_train_scaled
# Out:
# array([[-1.1576804 ,  0.97140947, -0.99692768, ..., -0.57266946,
#         -0.60581158, -0.57410974],
#        [-1.30061876,  0.97140947, -0.79276204, ..., -0.57266946,
#         -0.60581158, -0.57410974],
#        [ 0.91492586, -1.029432  ,  1.15466402, ...,  1.74620801,
#         -0.60581158, -0.57410974],
#        ...,
#        [-1.37208794,  0.97140947, -1.4118716 , ..., -0.57266946,
#         -0.60581158,  1.74182728],
#        [-0.08564268, -1.029432  , -0.41997378, ..., -0.57266946,
#         -0.60581158,  1.74182728],
#        [-0.30005022, -1.029432  ,  0.87941237, ..., -0.57266946,
#          1.65067825, -0.57410974]], shape=(1069, 9))

# %%
x_train_scaled = pd.DataFrame(x_train_scaled, columns=x_train.columns)
x_train_scaled
# Out:
#            age       sex       bmi  children    smoker  region_northeast  \
# 0    -1.157680  0.971409 -0.996928 -0.907908 -0.500292          1.795911
# 1    -1.300619  0.971409 -0.792762  0.766904 -0.500292          1.795911
# 2     0.914926 -1.029432  1.154664  0.766904 -0.500292         -0.556820
# 3     1.701087  0.971409  1.806837 -0.907908 -0.500292         -0.556820
# 4     0.557580 -1.029432 -0.651417  0.766904 -0.500292          1.795911
# ...        ...       ...       ...       ...       ...               ...
# 1064  0.843457 -1.029432  0.730628  0.766904  1.998831          1.795911
# 1065 -0.871804  0.971409  2.539188  0.766904 -0.500292         -0.556820
# 1066 -1.372088  0.971409 -1.411872 -0.070502 -0.500292         -0.556820
# 1067 -0.085643 -1.029432 -0.419974  1.604310 -0.500292         -0.556820
# 1068 -0.300050 -1.029432  0.879412  0.766904 -0.500292         -0.556820
#
#       region_northwest  region_southeast  region_southwest
# ...

# %%
x_test_scaled
# Out:
# array([[ 0.70051832,  0.97140947, -1.3267337 , ..., -0.57266946,
#         -0.60581158, -0.57410974],
#        [-0.72886531, -1.029432  , -0.8167329 , ..., -0.57266946,
#         -0.60581158,  1.74182728],
#        [ 0.84345668, -1.029432  ,  0.96620343, ...,  1.74620801,
#         -0.60581158, -0.57410974],
#        ...,
#        [-1.22914958, -1.029432  ,  0.6678075 , ..., -0.57266946,
#         -0.60581158, -0.57410974],
#        [ 1.5581485 ,  0.97140947,  0.95215155, ..., -0.57266946,
#         -0.60581158,  1.74182728],
#        [ 0.55757996, -1.029432  , -1.02833777, ..., -0.57266946,
#         -0.60581158, -0.57410974]], shape=(268, 9))

# %%
x_test_scaled = pd.DataFrame(x_test_scaled, columns=x_test.columns)
x_test_scaled
# Out:
#           age       sex       bmi  children    smoker  region_northeast  \
# 0    0.700518  0.971409 -1.326734 -0.907908 -0.500292          1.795911
# 1   -0.728865 -1.029432 -0.816733  2.441716 -0.500292         -0.556820
# 2    0.843457 -1.029432  0.966203  1.604310 -0.500292         -0.556820
# 3   -0.585927  0.971409  0.636397  1.604310  1.998831         -0.556820
# 4   -0.585927  0.971409  1.297663  0.766904 -0.500292         -0.556820
# ..        ...       ...       ...       ...       ...               ...
# 263  1.772556  0.971409  1.643174 -0.907908 -0.500292         -0.556820
# 264  1.701087 -1.029432  0.952152 -0.907908 -0.500292         -0.556820
# 265 -1.229150 -1.029432  0.667808  0.766904 -0.500292          1.795911
# 266  1.558148  0.971409  0.952152 -0.070502  1.998831         -0.556820
# 267  0.557580 -1.029432 -1.028338 -0.907908 -0.500292          1.795911
#
#      region_northwest  region_southeast  region_southwest
# ...

# %% [markdown]
# This Feature engineering aspect focuses on preparing the data for machine learning.
#
#  The categorical variables were converted into numerical values through encoding, while the numerical features were scaled where necessary to ensure they were on a similar range.
#
#  These steps helped the model understand the data more effectively, resulting in more accurate predictions of insurance costs.

# %% [markdown]
# ### Model Development
#
# Five regression models are trained using the processed and scaled dataset.
#
# The models include:
#
# - Linear Regression
# - Decision Tree Regressor
# - Random Forest Regressor
# - Gradient Boosting Regressor
# - AdaBoost Regressor

# %%
from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import (
    RandomForestRegressor,
    GradientBoostingRegressor,
    AdaBoostRegressor
)

import matplotlib.pyplot as plt
import pandas as pd

# Copy dataset
data = df.copy()

# Encode categorical columns
enc = LabelEncoder()
for c in data.select_dtypes(include='object').columns:
    data[c] = enc.fit_transform(data[c])


# Models

models = {
    "Decision Tree": DecisionTreeRegressor(random_state=42),
    "Random Forest": RandomForestRegressor(n_estimators=200, random_state=42),
    "Gradient Boosting": GradientBoostingRegressor(random_state=42),
    "AdaBoost": AdaBoostRegressor(random_state=42),
    "Linear Regression": LinearRegression()
}

# Train models and plot feature importance

for name, model in models.items():

    model.fit(x_train_scaled, y_train)

    if hasattr(model, "feature_importances_"):
        fi = pd.DataFrame({
            "Feature": x.columns,
            "Importance": model.feature_importances_
        })

    elif hasattr(model, "coef_"):
        fi = pd.DataFrame({
            "Feature": x.columns,
            "Importance": abs(model.coef_)
        })

    else:
        print(f"{name} does not support feature importance.")
        continue

    fi = fi.sort_values(by="Importance", ascending=False)

    print(f"\n{name}")
    display(fi)

    plt.figure(figsize=(8, 5))
    plt.barh(fi["Feature"], fi["Importance"])
    plt.gca().invert_yaxis()
    plt.title(f"{name} Feature Importance")
    plt.xlabel("Importance")
    plt.show()
# Out:
# Decision Tree
#             Feature  Importance
# 4            smoker    0.599279
# 2               bmi    0.210559
# 0               age    0.130371
# 3          children    0.023675
# 1               sex    0.011491
# 7  region_southeast    0.008989
# 6  region_northwest    0.007829
# 5  region_northeast    0.004310
# 8  region_southwest    0.003496
# Random Forest
#             Feature  Importance
# 4            smoker    0.599299
# 2               bmi    0.213470
# 0               age    0.137330
# 3          children    0.022981
# 1               sex    0.007092
# 6  region_northwest    0.005915
# 7  region_southeast    0.005266
# 5  region_northeast    0.004811
# 8  region_southwest    0.003835
# Gradient Boosting
#             Feature  Importance
# 4            smoker    0.670907
# 2               bmi    0.188273
# 0               age    0.122263
# 3          children    0.014194
# 5  region_northeast    0.001767
# 1               sex    0.000881
# ...

# %% [markdown]
# ### Model Evaluation
#
# Each trained model is evaluated using the following regression metrics:
#
# - Mean Absolute Error (MAE)
# - Mean Squared Error (MSE)
# - Root Mean Squared Error (RMSE)
# - R² Score
#
# The model with the highest R² Score and lowest prediction errors is selected as the final model.

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

results = []

for name, model in models.items():
    y_pred = model.predict(X_test_scaled)
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, y_pred)

    results.append({
        'Model': name,
        'MAE': mae,
        'MSE': mse,
        'RMSE': rmse,
        'R2': r2
    })

results_df = pd.DataFrame(results)
display(results_df.sort_values(by='R2',  ascending=False))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 6
#       2
#       3 results = []
#       4
#       5 for name, model in models.items():
# ----> 6     y_pred = model.predict(X_test_scaled)
#       7     mae = mean_absolute_error(y_test, y_pred)
#       8     mse = mean_squared_error(y_test, y_pred)
#       9     rmse = np.sqrt(mse)
#
# NameError: name 'X_test_scaled' is not defined

# %% [markdown]
# # Model Performance Report: Medical Insurance Cost Prediction
#
# ## Overview
#
# This report evaluates the performance of five regression models developed to predict medical insurance charges using the processed healthcare dataset.
#
# The models evaluated are:
#
# - Decision Tree Regressor
# - Random Forest Regressor
# - Gradient Boosting Regressor
# - AdaBoost Regressor
# - Linear Regression
#
# The models were assessed using the following evaluation metrics:
#
# - **MAE (Mean Absolute Error)**
# - **MSE (Mean Squared Error)**
# - **RMSE (Root Mean Squared Error)**
# - **R² Score (Coefficient of Determination)**
#
# ---
#
# ## Model Performance Summary
#
# | Model | MAE | MSE | RMSE | R² Score |
# |-------|------:|---------:|---------:|---------:|
# | Gradient Boosting | 2508.42 | 1.82 × 10⁷ | 4262.66 | **0.901** |
# | Random Forest | 2546.51 | 2.14 × 10⁷ | 4626.54 | **0.884** |
# | AdaBoost | 4905.64 | 3.10 × 10⁷ | 5570.55 | **0.831** |
# | Linear Regression | 4182.35 | 3.55 × 10⁷ | 5957.61 | **0.807** |
# | Decision Tree | 2942.89 | 4.02 × 10⁷ | 6338.36 | **0.781** |
#
# ---
#
# ## Interpretation of Evaluation Metrics
#
# ### R² Score (Coefficient of Determination)
#
# The R² score measures how well the model explains the variation in the target variable. Values closer to **1** indicate better predictive performance.
#
# ### Mean Absolute Error (MAE)
#
# MAE measures the average absolute difference between predicted and actual insurance charges. Lower values indicate more accurate predictions.
#
# ### Mean Squared Error (MSE)
#
# MSE measures the average squared prediction error. Larger errors are penalized more heavily, making it useful for identifying models with large prediction mistakes.
#
# ### Root Mean Squared Error (RMSE)
#
# RMSE is the square root of the MSE and represents the average prediction error in the same units as the target variable. Lower RMSE values indicate better model performance.
#
# ---
#
# ## Model Comparison
#
# - **Gradient Boosting Regressor** achieved the highest R² score (0.901) and the lowest prediction errors, making it the best-performing model.
# - **Random Forest Regressor** also performed well, achieving an R² score of 0.884 with relatively low error values.
# - **AdaBoost Regressor** showed good predictive performance but was less accurate than Gradient Boosting and Random Forest.
# - **Linear Regression** provided reasonable results but could not capture complex relationships in the data as effectively as the ensemble methods.
# - **Decision Tree Regressor** produced the lowest R² score and the highest RMSE, indicating that it was the least accurate model among those evaluated.
#
# ---
#
# ## Conclusion
#
# Among all the models evaluated, **Gradient Boosting Regressor** demonstrated the best overall predictive performance. It achieved the highest R² score while maintaining the lowest MAE, MSE, and RMSE values. Therefore, Gradient Boosting is selected as the most suitable model for predicting medical insurance costs in this project.

# %% [markdown]
# ## Save Best Model

# %%
import joblib

best_model_name = results_df.iloc[0]["Model"]

best_model = trained_models[best_model_name]

joblib.dump(
    best_model,
    "best_medical_insurance_model.pkl"
)

print(f"Best model: {best_model_name}")

print("Model saved successfully.")
# Out:
# ['gradient_boosting_model.joblib']
